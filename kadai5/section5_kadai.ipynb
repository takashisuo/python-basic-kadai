# %%
import sys, os

# %%
print(1+1)
# Out:
# 2

# %%
un1 = 1+2+3+5*10
un2 = 5*2-100
print(un1*un2)
# Out:
# -5040

# %%
user_name1 = "aさん"
user_name2 = "bさん"
user_name10 = "zさん"
print(user_name1, user_name2, user_name10)

user_names = ["aさん", "bさん", "zさん"]
print(user_names)
# Out:
# aさん bさん zさん
# ['aさん', 'bさん', 'zさん']

# %%
user_names = ["aさん", "bさん", "cさん", "zさん"]
print(user_names[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-497960588.py in <cell line: 0>()
#       1 user_names = ["aさん", "bさん", "cさん", "zさん"]
# ----> 2 user_names[4]
#
# IndexError: list index out of range

# %%
user_names = ["侍太郎", "侍一郎", "侍二郎", "侍三郎", "侍四郎"]
user_names.append("侍五郎")
user_names.append("侍五郎")
print(user_names)
# Out:
# ['侍太郎', '侍一郎', '侍二郎', '侍三郎', '侍四郎', '侍五郎', '侍五郎']

# %%
person_values = {"名前": "周防", "年齢": 40, "睡眠時間": 7}
name2age = {"周防": 40, "山田": 10}
name2age["周防"]
# Out:
# 40

# %%
sports = {1: "サッカー", 2: "野球", 3: "バスケット"}

# キー「2」の値を「バドミントン」に書き換える
sports[2] = "バドミントン"

# キー「4」として「水泳」を追加する
sports[4] = "水泳"

sports
# Out:
# {1: 'サッカー', 2: 'バドミントン', 3: 'バスケット', 4: '水泳'}

# %%
age = 10
if age >= 30 and age <= 50:
    print(age)
else:
    print("範囲外です")
# Out:
# 範囲外です
